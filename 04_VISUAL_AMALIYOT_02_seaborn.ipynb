# %% [markdown]
# <a href="https://colab.research.google.com/github/azamjon98/test/blob/main/04_VISUAL_AMALIYOT_02_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 2-AMALIYOT. `seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-VAZIFA. Avvalgi [amaliyotda](https://colab.research.google.com/drive/1jzhJ1gN6msILYOHaG2fhBBvUGaa4tcLf?usp=sharing) saqlangan faylni yangi `df`ga o'qing

# %%
#JAVOBINGIZNI SHU YERGA YOZING
df=pd.read_csv("/content/tashtemp.csv", index_col=0)
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
#@title Misol:
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %% [markdown]
# ### 2-VAZIFA. `df` barcha ustunlarini chiziqli grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,8))
plt.grid()
#plt.xlabel("Sana")
plt.xlabel('Yillar')
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
#plt.xticks(rotation=60, color='b')
sns.lineplot(data=df)
plt.show()

# %%
#@title Javob
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Grafiklar nomini to'g'rilang (`T`, `Tm` va hokazo matnlarni o'zbek tilida chiqaring.)

# %%
col=["O'rtacha yillik harorat",
"Yillik o'rtacha maksimal harorat",
"O'rtacha yillik minimal harorat",
"Yillik o'rtacha shamol tezligi",
"Yomg'irli kunlar soni",
"Qorli kunlar soni",
"Bo'ronli kunlar soni",
"Tumanli kunlar soni",
"Tornado bilan kunlar soni",
"Do'l yog'adigan kunlar soni"]
df1=pd.DataFrame(df, columns=col)
df1.head()
# Out:
#       O'rtacha yillik harorat  Yillik o'rtacha maksimal harorat  \
# Year
# 1991                     14.4                              21.2
# 1992                     14.4                              20.8
# 1993                     13.4                              19.6
# 1994                     14.4                              21.1
# 1995                     15.0                              22.2
#
#       O'rtacha yillik minimal harorat  Yillik o'rtacha shamol tezligi  \
# Year
# 1991                              8.3                             5.1
# 1992                              8.6                             5.1
# 1993                              7.6                             5.4
# 1994                              8.0                             5.1
# 1995                              8.4                             4.4
#
#       Yomg'irli kunlar soni  Qorli kunlar soni  Bo'ronli kunlar soni  \
# Year
# 1991                   77.0               26.0                  15.0
# 1992                   93.0               19.0                   9.0
# 1993                   98.0               38.0                  12.0
# 1994                   66.0               28.0                   4.0
# 1995                   41.0               20.0                   8.0
#
#       Tumanli kunlar soni  Tornado bilan kunlar soni  \
# Year
# 1991                 17.0                        0.0
# 1992                  2.0                        0.0
# 1993                 10.0                        1.0
# 1994                  9.0                        0.0
# 1995                 12.0                        0.0
#
#       Do'l yog'adigan kunlar soni
# Year
# 1991                          1.0
# 1992                          1.0
# 1993                          0.0
# 1994                          0.0
# 1995                          0.0

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,8))
plt.grid()
#plt.xlabel("Sana")
plt.xlabel('Yillar')
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
#plt.xticks(rotation=60, color='b')
sns.lineplot(data=df1)
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 4-VAZIFA. Yuqoridagi grafikda turli ko'rsatkichlar aralashib ketdi. Keling ustun turiga qarab alohida grafiklar chizamiz.
#
# #### 4.1. Haroratni ko'rsatuvchi ustunlarni alohida chiziqli grafik qilib chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,8))
plt.grid()
plt.ylabel("Harorat")
plt.xlabel('Yillar')
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
#plt.xticks(rotation=60, color='b')
sns.lineplot(data=df1[["O'rtacha yillik harorat",
"Yillik o'rtacha maksimal harorat",
"O'rtacha yillik minimal harorat"]])
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        # "Yomg'irli kunlar soni",
        # "Bo'ronli kunlar soni",
        # "Tumanli kunlar soni",
        # "To'fonli kunlar soni",
        # "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['T','TM','Tm']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# #### 4.2. Kunlarni ko'rsatuvchi ustunlarni alohida grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
col1=["Yomg'irli kunlar soni",
 'Qorli kunlar soni',
 "Bo'ronli kunlar soni",
 'Tumanli kunlar soni',
 'Tornado bilan kunlar soni',
 "Do'l yog'adigan kunlar soni"]
plt.figure(figsize=(16,8))
plt.grid()
plt.ylabel("kunlar soni")
plt.xlabel('Yillar')
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
sns.lineplot(data=df1[col1])
plt.show()

# %%
#@title Kutilgan natija:
labels=[
        # "Yillik o'rtacha harorat",
#         "Yillik o'rtacha maksimal harorat",
#         "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar soni"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['RA','SN','TS','FG','TN']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Kunlar")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. Yillik o'rtacha shamol tezligini ustunli grafik ko'rinishida chiqaring.

# %%
df1.index
df1[col2]
# Out:
#       Yillik o'rtacha shamol tezligi
# Year
# 1991                             5.1
# 1992                             5.1
# 1993                             5.4
# 1994                             5.1
# 1995                             4.4
# 1996                             5.0
# 1997                             5.0
# 1998                             5.0
# 1999                             7.6
# 2000                             8.0
# 2001                             8.2
# 2002                             8.2
# 2003                             7.8
# 2004                             7.7
# 2005                             7.7
# 2006                             9.1
# 2007                             9.0
# 2008                             8.8
# 2009                             9.0
# 2010                             9.0
# 2011                             9.5
# 2012                             9.4
# 2013                             9.6
# 2014                             9.5
# 2015                             9.9
# 2016                             9.9
# 2017                             9.9
# 2018                             9.7
# 2019                             9.8
# 2020                             9.8
# 2021                            10.0
# 2022                             9.8
# 2023                             9.8
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *["Yillik o'rtacha shamol tezligi"], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *["Yillik o'rtacha shamol tezligi"], **{})
# chart

# %%
#JAVOBINGIZNI SHU YERGA YOZING

col2 = ["Yillik o'rtacha shamol tezligi"]
plt.figure(figsize=(16, 8))
plt.grid()
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
plt.xticks(rotation=60, color='b')

# Create the bar plot
sns.barplot(x=df1.index, y=df1["Yillik o'rtacha shamol tezligi"])
plt.ylabel("Tezlik")
plt.xlabel('Yillar')
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(16,6))
sns.barplot(x=df.index, y=df['V'])
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.ylabel("O'rtacha shamol tezligi (km/soat)")
plt.xlabel("Yillar")
plt.xticks(rotation=90)
plt.show()

# %%
col3=["Yomg'irli kunlar soni",
 'Qorli kunlar soni',
 "Bo'ronli kunlar soni",
 'Tumanli kunlar soni',
 "Do'l yog'adigan kunlar soni"]

# %% [markdown]
# ### 6-VAZIFA. Yomg'rili, qorli, bo'ronli, tumanli va do'l yoqqan kunlar sonini heatmap ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(30,6))
plt.grid()
#plt.ylabel("kunlar soni")
#plt.xlabel('Yillar')
plt.title("Toshkent shahri yillik ob-havo ma'lumotlari")
sns.heatmap(data=df1[col3].T,cmap="Accent",annot=True)
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','GR']].T, cmap="YlGnBu", linewidths=1, square=True)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
yticks_labels = ["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+0.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
